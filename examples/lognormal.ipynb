# %%
# %matplotlib notebook

# %%
import sys

import torch.distributions as dist

# %%
sys.path.append('..')

from torchdistviz import distviz

# %%
distviz(dist.LogNormal)
# Out:
# <img src="data:image/png;base64,..." width="639.1304480330933">
# interactive(children=(BoundedFloatText(value=0.0, description='x_min'), BoundedFloatText(value=10.0, descripti…
